# %% [markdown]
# Palmer Penguins dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
df = pd.read_csv("F:\Akshay Files\DataSets\palmerpenguins.csv")
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
columns_to_keep = ['Sample Number',
                   'Species',
                   'Region',
                   'Island',
                   'Stage',
                   'Culmen Length (mm)',
                   'Culmen Depth (mm)',
                   'Flipper Length (mm)',
                   'Body Mass (g)'
                   ]
df = df[columns_to_keep]
df.head()
# Out:
#    Sample Number                              Species  Region     Island  \
# 0              1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1              2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2              3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3              4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4              5  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage  Culmen Length (mm)  Culmen Depth (mm)  \
# 0  Adult, 1 Egg Stage                39.1               18.7
# 1  Adult, 1 Egg Stage                39.5               17.4
# 2  Adult, 1 Egg Stage                40.3               18.0
# 3  Adult, 1 Egg Stage                 NaN                NaN
# 4  Adult, 1 Egg Stage                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)
# 0                181.0         3750.0
# 1                186.0         3800.0
# 2                195.0         3250.0
# 3                  NaN            NaN
# 4                193.0         3450.0

# %%
df.set_index("Sample Number")
#df = df.dropna(inplace = True)
df.head()
# Out:
#    Sample Number                              Species  Region     Island  \
# 0              1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1              2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2              3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3              4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4              5  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage  Culmen Length (mm)  Culmen Depth (mm)  \
# 0  Adult, 1 Egg Stage                39.1               18.7
# 1  Adult, 1 Egg Stage                39.5               17.4
# 2  Adult, 1 Egg Stage                40.3               18.0
# 3  Adult, 1 Egg Stage                 NaN                NaN
# 4  Adult, 1 Egg Stage                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)
# 0                181.0         3750.0
# 1                186.0         3800.0
# 2                195.0         3250.0
# 3                  NaN            NaN
# 4                193.0         3450.0

# %%
new = df["Species"].str.split("(", n = 1, expand = True)
df["Species"] = new[0]
df["Name"] = new[1]
df.head()
# Out:
#    Sample Number          Species  Region     Island               Stage  \
# 0              1  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 1              2  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 2              3  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 3              4  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 4              5  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#                   Name
# 0  Pygoscelis adeliae)
# 1  Pygoscelis adeliae)
# 2  Pygoscelis adeliae)
# 3  Pygoscelis adeliae)
# 4  Pygoscelis adeliae)

# %%
df["Label"] = new[0]
species = {'Adelie Penguin ':1, 'Chinstrap penguin ':2, 'Gentoo penguin ':3}
df.Label = [species[item] for item in df.Label]
df.head()
# Out:
#    Sample Number          Species  Region     Island               Stage  \
# 0              1  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 1              2  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 2              3  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 3              4  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
# 4              5  Adelie Penguin   Anvers  Torgersen  Adult, 1 Egg Stage
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#                   Name  Label
# 0  Pygoscelis adeliae)      1
# 1  Pygoscelis adeliae)      1
# 2  Pygoscelis adeliae)      1
# 3  Pygoscelis adeliae)      1
# 4  Pygoscelis adeliae)      1

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Culmen Length (mm)','Culmen Depth (mm)','Flipper Length (mm)','Body Mass (g)']]
X = X.fillna(X.mean())
y = df['Label']
y = y.fillna(y.mean())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
'''X_train.fillna(X_train.mean())
y_train.fillna(y_train.mean())
X_test.fillna(X_test.mean()) 
y_test.fillna(y_test.mean()) 
'''
# Out:
# 'X_train.fillna(X_train.mean())\ny_train.fillna(y_train.mean())\nX_test.fillna(X_test.mean()) \ny_test.fillna(y_test.mean()) \n'

# %%
# plotting a scatter matrix
from matplotlib import cm
from pandas.plotting import scatter_matrix

cmap = cm.get_cmap('gnuplot')
scatter = scatter_matrix(X_train, c= y_train, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(9,9), cmap=cmap)
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %%
# plotting a 3D scatter plot
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_train['Culmen Length (mm)'], X_train['Culmen Depth (mm)'], X_train['Flipper Length (mm)'], c = y_train, marker = 'o', s=20)
ax.set_xlabel('Culem length (mm)')
ax.set_ylabel('Culem Depth (mm)')
ax.set_zlabel('Flipper Lenth (mm)')
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# It's time for KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)

knn.score(X_test, y_test)
# Out:
# 0.8372093023255814

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
# we must apply the scaling to the test set that we computed for the training set
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(X_train_scaled, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train_scaled, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test_scaled, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.97

# %% [markdown]
# #### Using decision tree without max decision tree depth, the model is likely to overfit

# %%
#from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
#from adspy_shared_utilities import plot_decision_tree
#from sklearn.model_selection import train_test_split


#iris = load_iris()

#X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state = 3)
clf = DecisionTreeClassifier().fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.94

# %% [markdown]
# Look at the training aaccuracy and then look at test accuracy

# %% [markdown]
# #### Avoiding Overfitting

# %%
clf2 = DecisionTreeClassifier(max_depth = 4).fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf2.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.99
# Accuracy of Decision Tree classifier on test set: 0.97

# %% [markdown]
# See how the train accuracy decreased and the test accuracy increased by avoiding overfitting.
